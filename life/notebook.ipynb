# %%
import json
from config import *
import pandas as pd
with open(DATA_DIR+'/176529680581096/generation_data.json', 'r') as f:
    data = json.load(f)
death_counts = pd.Series({generation: data['prev_n_died']['# Diseased'] for generation, data in data.items()})
death_counts.plot()
# Out:
# <Axes: >
