# %%
import json
from config import *
import pandas as pd
with open(DATA_DIR+'/generation_data.json', 'r') as f:
    data = json.load(f)
death_counts = pd.Series({generation: data['prev_n_died'] for generation, data in data.items()})
death_counts.rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
# Out:
# <Axes: >

# %%
import random



print(hash)
# Out:
# 35847050323209
