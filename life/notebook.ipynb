# %%
import json
from config import *
import pandas as pd
with open(DATA_DIR+'/246607787131475/generation_data.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'1': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '2': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '3': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '4': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '5': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '6': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '7': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '8': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '9': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '10': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '11': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '12': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
#  '13': {'n_alive': 750, 'prev_n_died': {'# Died': 0, '# Diseased': 103}},
# ...

# %%
death_counts = pd.Series({generation: data['prev_n_died']['# Died'] for generation, data in data.items()})
death_counts.rolling(100).mean().plot()
# Out:
# <Axes: >

# %%
# Out:
# <Axes: >

# %%
import random



print(hash)
# Out:
# 35847050323209
